# %%
import pandas as pd
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
df = pd.read_csv('../Data/train.csv')

# %%
df.info()
df.drop(columns=['Team 1', 'Team2'], inplace=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7443 entries, 0 to 7442
# Data columns (total 21 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   season       7443 non-null   int64
#  1   date         7443 non-null   object
#  2   league_id    7443 non-null   int64
#  3   league       7443 non-null   object
#  4   Team 1       7443 non-null   object
#  5   Team2        7443 non-null   object
#  6   SPI1         7443 non-null   float64
#  7   SPI2         7443 non-null   float64
#  8   proj_score1  7443 non-null   float64
#  9   proj_score2  7443 non-null   float64
#  10  importance1  2527 non-null   float64
#  11  importance2  2527 non-null   float64
#  12  score1       2643 non-null   float64
#  13  score2       2643 non-null   float64
#  14  xg1          1715 non-null   float64
#  15  xg2          1715 non-null   float64
#  16  nsxg1        1715 non-null   float64
#  17  nsxg2        1715 non-null   float64
#  18  adj_score1   1715 non-null   float64
#  19  adj_score2   1715 non-null   float64
#  20  Outcome      7443 non-null   int64
# dtypes: float64(14), int64(3), object(4)
# memory usage: 1.2+ MB

# %%
df.hist(figsize=(20, 20), bins=50)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000026E39420C40>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026E394B4A00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026E394E2E50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026E3951A610>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000026E39544A60>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026E39572DF0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026E39572EE0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026E395A93D0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000026E39601BE0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026E3962D0D0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026E396674F0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026E39692940>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000026E396BFD90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026E396F7220>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026E39722670>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026E3974FAF0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000026E3977CF70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026E397B6340>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026E397D4940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026E39802D90>]],
#       dtype=object)

# %%
cat_cols = list(df.select_dtypes('object').columns)
cat_cols = cat_cols + ['season']
cat_cols.remove('date')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-63-6f69bca37265> in <module>
#       1 cat_cols = list(df.select_dtypes('object').columns)
#       2 cat_cols = cat_cols + ['season']
# ----> 3 cat_cols.remove('date')
#
# ValueError: list.remove(x): x not in list

# %%
for x in cat_cols:
    print(f"""
    {df[x].value_counts(ascending=False)}
    
    """)
# Out:
#     United Soccer League                        496
# Major League Soccer                         459
# Brasileiro Série A                          380
# Japanese J League                           380
# APD                                         325
# English League Championship                 264
# English League One                          264
# English League Two                          252
# Swedish Allsvenskan                         240
# Chinese Super League                        240
# Norwegian Tippeligaen                       240
# Spanish Segunda Division                    220
# UEFA Europa League                          204
# French Ligue 1                              180
# French Ligue 2                              180
# Mexican Primera Division Torneo Clausura    171
# Italy Serie B                               170
# Spanish Primera Division                    170
# Italy Serie A                               170
# BJL                                         162
# AAL                                         161
# BPL                                         160
# TTSL                                        160
# German 2. Bundesliga                        153
# Mexican Primera Division Torneo Apertura    153
# Dutch Eredivisie                            144
# Russian Premier Liga                        144
# German Bundesliga                           135
# Portuguese Liga                             126
# UEFA Champions League                       125
# National Women's Soccer League              120
# South African ABSA Premier League           119
# Scottish Premiership                        108
# ATMB                                        108
# Danish SAS-Ligaen                           102
# Greek Super League                           98
# Swiss Raiffeisen Super League                85
# FA Women's Super League                      54
# NWSL Challenge Cup                           21
# Name: league, dtype: int64
#
#
#
#     2021    6542
# 2020     661
# 2019     240
# Name: season, dtype: int64

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
def ConvertUnix(x):
    y = pd.Timestamp(x).timestamp()
    y = int(y)
    return y

df['date'] = df['date'].apply(ConvertUnix)

df['date'] = 1 / df['date']

# %%
num_cols = list(df.select_dtypes(include=['int64', 'float64']).columns)
num_cols.remove('season')
num_cols.remove('Outcome')


root_cols = [
    'SPI1',
    'SPI2',
    'proj_score1',
    'proj_score2',
    'importance1',
    'importance2',
    'xg1',
    'xg2',
    'nsxg1',
    'nsxg2',
    'score1',
    'score2'
]

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# adj_score1     5728
# nsxg2          5728
# nsxg1          5728
# xg2            5728
# xg1            5728
# adj_score2     5728
# importance2    4916
# importance1    4916
# score2         4800
# score1         4800
# SPI1              0
# date              0
# league_id         0
# league            0
# Outcome           0
# SPI2              0
# proj_score1       0
# proj_score2       0
# season            0
# dtype: int64

# %%
null_cols = [
    'adj_score1',
    'nsxg2',
    'nsxg1',
    'xg2',
    'xg1',
    'adj_score2',
    'importance2',
    'importance1',
]

log_cols = [
    'adj_score1',
    'adj_score2',
]

# %%
from sklearn.impute import SimpleImputer

imputer = SimpleImputer(strategy='mean')
df[num_cols] = imputer.fit_transform(df[num_cols])
df
# Out:
#       season          date  league_id                             league  \
# 0       2019  6.466324e-10     1979.0               Chinese Super League
# 1       2019  6.466324e-10     1979.0               Chinese Super League
# 2       2019  6.466324e-10     1979.0               Chinese Super League
# 3       2019  6.466324e-10     1979.0               Chinese Super League
# 4       2019  6.466324e-10     1979.0               Chinese Super League
# ...      ...           ...        ...                                ...
# 7438    2021  6.100287e-10     1846.0               German 2. Bundesliga
# 7439    2021  6.100287e-10     1846.0               German 2. Bundesliga
# 7440    2021  6.099644e-10     1983.0  South African ABSA Premier League
# 7441    2021  6.099644e-10     1983.0  South African ABSA Premier League
# 7442    2021  6.099644e-10     1983.0  South African ABSA Premier League
#
#        SPI1   SPI2  proj_score1  proj_score2  importance1  importance2  \
# 0     48.22  37.83         1.75         0.84    45.900000    22.100000
# 1     39.81  60.08         1.22         1.89    25.600000    63.400000
# 2     65.59  39.99         2.58         0.62    77.100000    28.800000
# 3     32.25  54.82         1.10         1.79    35.800000    58.900000
# 4     38.24  40.45         1.57         1.24    26.200000    21.300000
# ...     ...    ...          ...          ...          ...          ...
# 7438  34.05  33.76         1.39         1.19    32.668421    31.957776
# 7439  36.73  36.11         1.67         1.44    32.668421    31.957776
# 7440  12.97  23.59         1.05         1.50    32.668421    31.957776
# 7441  11.76  18.07         1.22         1.46    32.668421    31.957776
# 7442  25.89  10.75         1.41         0.59    32.668421    31.957776
#
#         score1    score2       xg1       xg2     nsxg1   nsxg2  adj_score1  \
# 0     1.000000  0.000000  1.390000  0.260000  2.050000  0.5400     1.05000
# 1     0.000000  4.000000  0.570000  2.760000  0.800000  1.5000     0.00000
# 2     3.000000  0.000000  0.490000  0.450000  1.050000  0.7500     3.15000
# 3     0.000000  1.000000  1.120000  0.970000  1.510000  0.9400     0.00000
# 4     2.000000  2.000000  2.770000  3.170000  1.050000  2.0800     2.10000
# ...        ...       ...       ...       ...       ...     ...         ...
# 7438  1.482785  1.196746  1.462035  1.169376  1.360292  1.1087     1.51014
# 7439  1.482785  1.196746  1.462035  1.169376  1.360292  1.1087     1.51014
# 7440  1.482785  1.196746  1.462035  1.169376  1.360292  1.1087     1.51014
# 7441  1.482785  1.196746  1.462035  1.169376  1.360292  1.1087     1.51014
# 7442  1.482785  1.196746  1.462035  1.169376  1.360292  1.1087     1.51014
#
#       adj_score2  Outcome
# 0           0.00        1
# 1           3.26        0
# 2           0.00        1
# 3           1.05        0
# 4           2.10        1
# ...          ...      ...
# 7438        1.23        1
# 7439        1.23        1
# 7440        1.23        0
# 7441        1.23        0
# 7442        1.23        1
#
# [7443 rows x 19 columns]

# %%
df[root_cols] = np.sqrt(df[root_cols])

# %%
df.hist(figsize=(20,20), bins=50)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000026E80A40250>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026E806E4310>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026E8037FE50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026E803A9F70>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000026E803E2400>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026E8040E790>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026E8040E880>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026E8043AD30>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000026E8049F580>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026E804CE9D0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026E804FBE20>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026E805352B0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000026E8055F700>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026E8058CB50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026E805B9FA0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026E805F3460>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000026E8061E8B0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026E8064BD00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026E806850D0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026E806A66D0>]],
#       dtype=object)

# %% [markdown]
# # Preprocessing

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import MinMaxScaler, StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer

X = df.drop(columns=['Outcome'])
y = df[['Outcome']]

num_pipeline = Pipeline([
    ('std_scaler', StandardScaler())
])

full_pipeline = ColumnTransformer([
    ('roots', num_pipeline, root_cols),
    ('nums', num_pipeline, num_cols),
    ('cat', OneHotEncoder(), cat_cols)
])

# %%
X_trans = full_pipeline.fit_transform(X)

# %%
y = np.asarray(y)

# %% [markdown]
# # Train Test Split

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X_trans, y, test_size=0.2, random_state=42, shuffle=True)

# %%
# Out:
# array([[-0.21340742, -0.21466756,  0.29668178, ...,  0.        ,
#          0.        ,  1.        ],
#        [ 1.16393315,  0.81434626,  0.58829477, ...,  0.        ,
#          0.        ,  1.        ],
#        [-0.53241797, -0.7645955 , -0.08986908, ...,  0.        ,
#          0.        ,  1.        ],
#        ...,
#        [ 0.27879611,  1.14383404, -0.89396485, ...,  0.        ,
#          0.        ,  1.        ],
#        [ 0.65693634,  0.65090125, -0.98894713, ...,  0.        ,
#          1.        ,  0.        ],
#        [ 1.37028311,  1.889956  ,  0.29668178, ...,  0.        ,
#          1.        ,  0.        ]])

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score

rf = RandomForestClassifier()

base_model = rf.fit(X_train, y_train)

# %%
predictions = base_model.predict_proba(X_test)

cross_val_score(base_model, X_test, y_test, cv=5, scoring='neg_log_loss').mean()

# %% [markdown]
# # Neural Network

# %%
from tensorflow import keras
from keras.callbacks import ModelCheckpoint
from keras.models import load_model
from datetime import datetime

today = datetime.today()
today = str(today.date()) + ' ' + str(today.hour) + '-' + str(today.minute)

# %%
today
# Out:
# '2021-08-24 21-12'

# %%
mc = ModelCheckpoint(f'../Models/soccer_model {today}.h5', 
                     monitor='val_loss', mode='min', verbose=1, save_best_only=True)

# %%
X_train.shape
# Out:
# (5954, 70)

# %%
model = keras.Sequential([
    keras.layers.Dense(75, activation='relu', input_dim=70),
    keras.layers.Dense(500, activation='relu'),
    keras.layers.Dense(600, activation='relu'),
    keras.layers.Dense(500, activation='relu'),
    keras.layers.Dense(100, activation='relu'),
    keras.layers.Dense(50, activation='relu'),
    keras.layers.Dense(250, activation='relu'),
    keras.layers.Dense(1, activation='sigmoid')
])

# %%
model.compile(optimizer='adam',
             loss=keras.losses.BinaryCrossentropy(),
             metrics=[keras.metrics.BinaryCrossentropy(), 'accuracy'])

# %%
history = model.fit(
    X_train,
    y_train,
    batch_size=200,
    epochs=150,
    validation_data=(X_test, y_test),
    shuffle=True,
    callbacks=mc)
# Out:
# Epoch 1/150
# 30/30 [==============================] - 1s 15ms/step - loss: 0.2325 - binary_crossentropy: 0.2325 - accuracy: 0.9157 - val_loss: 0.1059 - val_binary_crossentropy: 0.1059 - val_accuracy: 0.9631
#
# Epoch 00001: val_loss did not improve from 0.05808
# Epoch 2/150
# 30/30 [==============================] - 0s 9ms/step - loss: 0.0852 - binary_crossentropy: 0.0852 - accuracy: 0.9667 - val_loss: 0.0758 - val_binary_crossentropy: 0.0758 - val_accuracy: 0.9704
#
# Epoch 00002: val_loss did not improve from 0.05808
# Epoch 3/150
# 30/30 [==============================] - 0s 9ms/step - loss: 0.0658 - binary_crossentropy: 0.0658 - accuracy: 0.9746 - val_loss: 0.0994 - val_binary_crossentropy: 0.0994 - val_accuracy: 0.9738
#
# Epoch 00003: val_loss did not improve from 0.05808
# Epoch 4/150
# 30/30 [==============================] - 0s 10ms/step - loss: 0.0485 - binary_crossentropy: 0.0485 - accuracy: 0.9812 - val_loss: 0.0617 - val_binary_crossentropy: 0.0617 - val_accuracy: 0.9805
#
# Epoch 00004: val_loss did not improve from 0.05808
# Epoch 5/150
# 30/30 [==============================] - 0s 10ms/step - loss: 0.0354 - binary_crossentropy: 0.0354 - accuracy: 0.9879 - val_loss: 0.0588 - val_binary_crossentropy: 0.0588 - val_accuracy: 0.9819
#
# Epoch 00005: val_loss did not improve from 0.05808
# Epoch 6/150
# 30/30 [==============================] - 0s 9ms/step - loss: 0.0300 - binary_crossentropy: 0.0300 - accuracy: 0.9884 - val_loss: 0.0766 - val_binary_crossentropy: 0.0766 - val_accuracy: 0.9772
#
# Epoch 00006: val_loss did not improve from 0.05808
# Epoch 7/150
# 30/30 [==============================] - 0s 10ms/step - loss: 0.0276 - binary_crossentropy: 0.0276 - accuracy: 0.9893 - val_loss: 0.0655 - val_binary_crossentropy: 0.0655 - val_accuracy: 0.9832
#
# Epoch 00007: val_loss did not improve from 0.05808
# Epoch 8/150
# 30/30 [==============================] - 0s 9ms/step - loss: 0.0264 - binary_crossentropy: 0.0264 - accuracy: 0.9898 - val_loss: 0.0600 - val_binary_crossentropy: 0.0600 - val_accuracy: 0.9859
#
# Epoch 00008: val_loss did not improve from 0.05808
# Epoch 9/150
# 30/30 [==============================] - 0s 9ms/step - loss: 0.0140 - binary_crossentropy: 0.0140 - accuracy: 0.9948 - val_loss: 0.0845 - val_binary_crossentropy: 0.0845 - val_accuracy: 0.9812
#
# Epoch 00009: val_loss did not improve from 0.05808
# Epoch 10/150
# 30/30 [==============================] - 0s 9ms/step - loss: 0.0222 - binary_crossentropy: 0.0222 - accuracy: 0.9914 - val_loss: 0.0708 - val_binary_crossentropy: 0.0708 - val_accuracy: 0.9812
#
# Epoch 00010: val_loss did not improve from 0.05808
# Epoch 11/150
# 30/30 [==============================] - 0s 9ms/step - loss: 0.0143 - binary_crossentropy: 0.0143 - accuracy: 0.9945 - val_loss: 0.0758 - val_binary_crossentropy: 0.0758 - val_accuracy: 0.9852
#
# Epoch 00011: val_loss did not improve from 0.05808
# Epoch 12/150
# 30/30 [==============================] - 0s 9ms/step - loss: 0.0147 - binary_crossentropy: 0.0147 - accuracy: 0.9945 - val_loss: 0.0873 - val_binary_crossentropy: 0.0873 - val_accuracy: 0.9819
#
# Epoch 00012: val_loss did not improve from 0.05808
# Epoch 13/150
# 30/30 [==============================] - 0s 9ms/step - loss: 0.0194 - binary_crossentropy: 0.0194 - accuracy: 0.9923 - val_loss: 0.0711 - val_binary_crossentropy: 0.0711 - val_accuracy: 0.9839
#
# Epoch 00013: val_loss did not improve from 0.05808
# Epoch 14/150
# 30/30 [==============================] - 0s 9ms/step - loss: 0.0100 - binary_crossentropy: 0.0100 - accuracy: 0.9961 - val_loss: 0.0799 - val_binary_crossentropy: 0.0799 - val_accuracy: 0.9846
#
# Epoch 00014: val_loss did not improve from 0.05808
# Epoch 15/150
# 30/30 [==============================] - 0s 9ms/step - loss: 0.0194 - binary_crossentropy: 0.0194 - accuracy: 0.9924 - val_loss: 0.0863 - val_binary_crossentropy: 0.0863 - val_accuracy: 0.9812
#
# Epoch 00015: val_loss did not improve from 0.05808
# Epoch 16/150
# 30/30 [==============================] - 0s 9ms/step - loss: 0.0250 - binary_crossentropy: 0.0250 - accuracy: 0.9899 - val_loss: 0.0792 - val_binary_crossentropy: 0.0792 - val_accuracy: 0.9805
#
# Epoch 00016: val_loss did not improve from 0.05808
# Epoch 17/150
# 30/30 [==============================] - 0s 9ms/step - loss: 0.0127 - binary_crossentropy: 0.0127 - accuracy: 0.9941 - val_loss: 0.0704 - val_binary_crossentropy: 0.0704 - val_accuracy: 0.9846
#
# Epoch 00017: val_loss did not improve from 0.05808
# Epoch 18/150
# 30/30 [==============================] - 0s 10ms/step - loss: 0.0111 - binary_crossentropy: 0.0111 - accuracy: 0.9958 - val_loss: 0.0794 - val_binary_crossentropy: 0.0794 - val_accuracy: 0.9872
#
# Epoch 00018: val_loss did not improve from 0.05808
# Epoch 19/150
# 30/30 [==============================] - 0s 9ms/step - loss: 0.0059 - binary_crossentropy: 0.0059 - accuracy: 0.9970 - val_loss: 0.0972 - val_binary_crossentropy: 0.0972 - val_accuracy: 0.9866
#
# Epoch 00019: val_loss did not improve from 0.05808
# Epoch 20/150
# 30/30 [==============================] - 0s 9ms/step - loss: 0.0054 - binary_crossentropy: 0.0054 - accuracy: 0.9976 - val_loss: 0.0849 - val_binary_crossentropy: 0.0849 - val_accuracy: 0.9872
#
# Epoch 00020: val_loss did not improve from 0.05808
# Epoch 21/150
# 30/30 [==============================] - 0s 9ms/step - loss: 0.0049 - binary_crossentropy: 0.0049 - accuracy: 0.9983 - val_loss: 0.0933 - val_binary_crossentropy: 0.0933 - val_accuracy: 0.9866
#
# Epoch 00021: val_loss did not improve from 0.05808
# Epoch 22/150
# 30/30 [==============================] - 0s 9ms/step - loss: 0.0058 - binary_crossentropy: 0.0058 - accuracy: 0.9975 - val_loss: 0.0927 - val_binary_crossentropy: 0.0927 - val_accuracy: 0.9872
#
# Epoch 00022: val_loss did not improve from 0.05808
# Epoch 23/150
# 30/30 [==============================] - 0s 10ms/step - loss: 0.0031 - binary_crossentropy: 0.0031 - accuracy: 0.9987 - val_loss: 0.1066 - val_binary_crossentropy: 0.1066 - val_accuracy: 0.9893
#
# Epoch 00023: val_loss did not improve from 0.05808
# Epoch 24/150
# 30/30 [==============================] - 0s 9ms/step - loss: 0.0068 - binary_crossentropy: 0.0068 - accuracy: 0.9970 - val_loss: 0.0949 - val_binary_crossentropy: 0.0949 - val_accuracy: 0.9846
#
# Epoch 00024: val_loss did not improve from 0.05808
# Epoch 25/150
# 30/30 [==============================] - 0s 9ms/step - loss: 0.0062 - binary_crossentropy: 0.0062 - accuracy: 0.9983 - val_loss: 0.0830 - val_binary_crossentropy: 0.0830 - val_accuracy: 0.9866
#
# Epoch 00025: val_loss did not improve from 0.05808
# Epoch 26/150
# 30/30 [==============================] - 0s 10ms/step - loss: 0.0065 - binary_crossentropy: 0.0065 - accuracy: 0.9980 - val_loss: 0.0878 - val_binary_crossentropy: 0.0878 - val_accuracy: 0.9866
#
# Epoch 00026: val_loss did not improve from 0.05808
# Epoch 27/150
# 30/30 [==============================] - 0s 10ms/step - loss: 0.0041 - binary_crossentropy: 0.0041 - accuracy: 0.9985 - val_loss: 0.1243 - val_binary_crossentropy: 0.1243 - val_accuracy: 0.9819
#
# Epoch 00027: val_loss did not improve from 0.05808
# Epoch 28/150
# 30/30 [==============================] - 0s 9ms/step - loss: 0.0098 - binary_crossentropy: 0.0098 - accuracy: 0.9963 - val_loss: 0.0898 - val_binary_crossentropy: 0.0898 - val_accuracy: 0.9812
#
# Epoch 00028: val_loss did not improve from 0.05808
# Epoch 29/150
# 30/30 [==============================] - 0s 10ms/step - loss: 0.0184 - binary_crossentropy: 0.0184 - accuracy: 0.9936 - val_loss: 0.0644 - val_binary_crossentropy: 0.0644 - val_accuracy: 0.9832
#
# Epoch 00029: val_loss did not improve from 0.05808
# Epoch 30/150
# 30/30 [==============================] - 0s 10ms/step - loss: 0.0109 - binary_crossentropy: 0.0109 - accuracy: 0.9968 - val_loss: 0.1007 - val_binary_crossentropy: 0.1007 - val_accuracy: 0.9839
#
# Epoch 00030: val_loss did not improve from 0.05808
# Epoch 31/150
# 30/30 [==============================] - 0s 9ms/step - loss: 0.0162 - binary_crossentropy: 0.0162 - accuracy: 0.9934 - val_loss: 0.0773 - val_binary_crossentropy: 0.0773 - val_accuracy: 0.9832
#
# Epoch 00031: val_loss did not improve from 0.05808
# Epoch 32/150
# 30/30 [==============================] - 0s 10ms/step - loss: 0.0043 - binary_crossentropy: 0.0043 - accuracy: 0.9985 - val_loss: 0.1159 - val_binary_crossentropy: 0.1159 - val_accuracy: 0.9866
#
# Epoch 00032: val_loss did not improve from 0.05808
# Epoch 33/150
# 30/30 [==============================] - 0s 11ms/step - loss: 0.0050 - binary_crossentropy: 0.0050 - accuracy: 0.9978 - val_loss: 0.1362 - val_binary_crossentropy: 0.1362 - val_accuracy: 0.9852
#
# Epoch 00033: val_loss did not improve from 0.05808
# Epoch 34/150
# 30/30 [==============================] - 0s 10ms/step - loss: 0.0077 - binary_crossentropy: 0.0077 - accuracy: 0.9980 - val_loss: 0.1185 - val_binary_crossentropy: 0.1185 - val_accuracy: 0.9832
#
# Epoch 00034: val_loss did not improve from 0.05808
# Epoch 35/150
# 30/30 [==============================] - 0s 11ms/step - loss: 0.0051 - binary_crossentropy: 0.0051 - accuracy: 0.9987 - val_loss: 0.1350 - val_binary_crossentropy: 0.1350 - val_accuracy: 0.9825
#
# Epoch 00035: val_loss did not improve from 0.05808
# Epoch 36/150
# 19/30 [==================>...........] - ETA: 0s - loss: 0.0030 - binary_crossentropy: 0.0030 - accuracy: 0.9989
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-45-93c43e6ad9c2> in <module>
# ----> 1 history = model.fit(
#       2     X_train,
#       3     y_train,
#       4     batch_size=200,
#       5     epochs=150,
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1181                 _r=1):
#    1182               callbacks.on_train_batch_begin(step)
# -> 1183               tmp_logs = self.train_function(iterator)
#    1184               if data_handler.should_sync:
#    1185                 context.async_wait()
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py in __call__(self, *args, **kwds)
#     887
#     888       with OptionalXlaContext(self._jit_compile):
# --> 889         result = self._call(*args, **kwds)
#     890
#     891       new_tracing_count = self.experimental_get_tracing_count()
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py in _call(self, *args, **kwds)
#     915       # In this case we have created variables on the first call, so we run the
#     916       # defunned version which is guaranteed to never create variables.
# --> 917       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     918     elif self._stateful_fn is not None:
#     919       # Release the lock early so that multiple threads can perform the call
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\eager\function.py in __call__(self, *args, **kwargs)
#    3021       (graph_function,
#    3022        filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 3023     return graph_function._call_flat(
#    3024         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    3025
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\eager\function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1958         and executing_eagerly):
#    1959       # No tape is watching; skip to running the function.
# -> 1960       return self._build_call_outputs(self._inference_function.call(
#    1961           ctx, args, cancellation_manager=cancellation_manager))
#    1962     forward_backward = self._select_forward_and_backward_functions(
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\eager\function.py in call(self, ctx, args, cancellation_manager)
#     589       with _InterpolateFunctionError(self):
#     590         if cancellation_manager is None:
# --> 591           outputs = execute.execute(
#     592               str(self.signature.name),
#     593               num_outputs=self._num_outputs,
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      57   try:
#      58     ctx.ensure_initialized()
# ---> 59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
model = load_model(f'../Models/soccer_model {today}.h5')

# %% [markdown]
# # Run on Test Data

# %%
test = pd.read_csv('../Data/test.csv')

# %%
test.drop(columns=['Team 1', 'Team2'], inplace=True)

# %%
test['date'] = pd.to_datetime(test['date'])

# %%
def ConvertUnix(x):
    y = pd.Timestamp(x).timestamp()
    y = int(y)
    return y

test['date'] = test['date'].apply(ConvertUnix)

test['date'] = 1 / test['date']

# %%
test
# Out:
#       season          date  league_id                    league   SPI1   SPI2  \
# 0       2021  6.099644e-10       2411                       BPL  79.65  74.06
# 1       2021  6.099644e-10       2411                       BPL  74.19  71.14
# 2       2021  6.099644e-10       2411                       BPL  60.67  71.45
# 3       2021  6.099644e-10       2411                       BPL  76.88  79.06
# 4       2021  6.099644e-10       2411                       BPL  63.53  85.58
# ...      ...           ...        ...                       ...    ...    ...
# 4003    2021  6.046745e-10       1871  Spanish Segunda Division  41.51  48.12
# 4004    2021  6.046745e-10       1871  Spanish Segunda Division  26.77  33.53
# 4005    2021  6.046745e-10       1871  Spanish Segunda Division  26.62  28.65
# 4006    2021  6.046745e-10       1871  Spanish Segunda Division  33.74  30.32
# 4007    2021  6.046745e-10       1871  Spanish Segunda Division  29.70  30.25
#
#       proj_score1  proj_score2  importance1  importance2  score1  score2  xg1  \
# 0            1.67         1.19          NaN          NaN     NaN     NaN  NaN
# 1            1.35         0.98          NaN          NaN     NaN     NaN  NaN
# 2            1.18         1.49          NaN          NaN     NaN     NaN  NaN
# 3            1.52         1.44          NaN          NaN     NaN     NaN  NaN
# 4            0.95         1.92          NaN          NaN     NaN     NaN  NaN
# ...           ...          ...          ...          ...     ...     ...  ...
# 4003         1.40         1.39          NaN          NaN     NaN     NaN  NaN
# 4004         1.17         1.18          NaN          NaN     NaN     NaN  NaN
# 4005         1.31         1.14          NaN          NaN     NaN     NaN  NaN
# 4006         1.33         0.87          NaN          NaN     NaN     NaN  NaN
# 4007         1.38         1.19          NaN          NaN     NaN     NaN  NaN
#
#       xg2  nsxg1  nsxg2  adj_score1  adj_score2
# 0     NaN    NaN    NaN         NaN         NaN
# 1     NaN    NaN    NaN         NaN         NaN
# 2     NaN    NaN    NaN         NaN         NaN
# 3     NaN    NaN    NaN         NaN         NaN
# 4     NaN    NaN    NaN         NaN         NaN
# ...   ...    ...    ...         ...         ...
# 4003  NaN    NaN    NaN         NaN         NaN
# 4004  NaN    NaN    NaN         NaN         NaN
# 4005  NaN    NaN    NaN         NaN         NaN
# 4006  NaN    NaN    NaN         NaN         NaN
# 4007  NaN    NaN    NaN         NaN         NaN
#
# [4008 rows x 18 columns]

# %%
test[num_cols] = imputer.transform(test[num_cols])

# %%
test[root_cols] = np.sqrt(test[root_cols])

# %%
test = full_pipeline.transform(test)

# %%
test
# Out:
# array([[ 1.83288199,  1.61864163,  0.6143192 , ...,  0.        ,
#          0.        ,  1.        ],
#        [ 1.62489348,  1.5040859 , -0.26139323, ...,  0.        ,
#          0.        ,  1.        ],
#        [ 1.07421802,  1.51635783, -0.76924515, ...,  0.        ,
#          0.        ,  1.        ],
#        ...,
#        [-0.68258807, -0.55619557, -0.37786867, ...,  0.        ,
#          0.        ,  1.        ],
#        [-0.24889984, -0.45338453, -0.319412  , ...,  0.        ,
#          0.        ,  1.        ],
#        [-0.48863581, -0.45763625, -0.17516501, ...,  0.        ,
#          0.        ,  1.        ]])

# %%
predictions = model.predict(test)

# %%
submission = pd.DataFrame(predictions, columns=['Outcome'])

# %%
submission.to_csv(f"../Submissions/{today} Submission.csv", index=False)

# %%
predictions
# Out:
# array([[1.],
#        [1.],
#        [0.],
#        ...,
#        [1.],
#        [1.],
#        [1.]], dtype=float32)

# %%
submission['Outcome'].value_counts()
# Out:
# 1.000000    2691
# 0.000000    1078
# 0.032301       1
# 0.006633       1
# 0.371762       1
#             ...
# 0.426946       1
# 0.074509       1
# 0.417160       1
# 0.560874       1
# 0.982230       1
# Name: Outcome, Length: 241, dtype: int64
